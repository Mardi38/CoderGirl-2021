# %% [markdown]
# # Exploratory Data Analysis part 1 Studio
#
# ## Data Analysis of IMDB movies data
#
# #### The studio will continue working through the ["A Comprehensive Guide To Data Analysis using Pandas: Hands-On Data Analysis on IMDB movies data"](https://www.analyticsvidhya.com/blog/2021/05/a-comprehensive-guide-to-data-analysis-using-pandas-hands-on-data-analysis-on-imdb-movies-data/) in the **Data Analysis of IMDB movies data** section
#
# #### Blocks have been created for your code
#
# #### Follow the link in the article to download the dataset from [Kaggle](https://www.kaggle.com/PromptCloudHQ/imdb-data).  Link contained within the article.

# %% [markdown]
# ### 1. Read data

# %%
# import pandas
import pandas as pd
import numpy as np

# create your data variabe using .read_csv 
Movie = pd.read_csv('IMDB-Movie-Data.csv')
#in the same file tree

# create your data_indexed varialbe here
Movie_indexed = pd.read_csv('IMDB-Movie-Data.csv', index_col = "Title")

# %%
Movie
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# 1    Following clues to the origin of mankind, a te...          Ridley Scott
# 2    Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3    In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4    A secret government agency recruits some of th...            David Ayer
# ..                                                 ...                   ...
# 995  A tight-knit team of rising investigators, alo...             Billy Ray
# 996  Three American college students studying abroa...              Eli Roth
# 997  Romantic sparks occur between two dance studen...            Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...        Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...      Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012
# 2    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016
# 3    Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016
# 4    Will Smith, Jared Leto, Margot Robbie, Viola D...  2016
# ..                                                 ...   ...
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# 996  Lauren German, Heather Matarazzo, Bijou Philli...  2007
# 997  Robert Hoffman, Briana Evigan, Cassie Ventura,...  2008
# 998  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014
# 999  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 0                  121     8.1  757074              333.13       76.0
# 1                  124     7.0  485820              126.46       65.0
# 2                  117     7.3  157606              138.12       62.0
# 3                  108     7.2   60545              270.32       59.0
# 4                  123     6.2  393727              325.02       40.0
# ..                 ...     ...     ...                 ...        ...
# 995                111     6.2   27585                 NaN       45.0
# 996                 94     5.5   73152               17.54       46.0
# 997                 98     6.2   70699               58.01       50.0
# 998                 93     5.6    4881                 NaN       22.0
# 999                 87     5.3   12435               19.64       11.0
#
# [1000 rows x 12 columns]

# %%
Movie_indexed
#now the titles are the first column.
# create your data_indexed varialbe here
#Movie_indexed = pd.read_csv('IMDB-Movie-Data.csv', index_col = "Title")
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
# ...                                                                    ...
# Secret in Their Eyes     A tight-knit team of rising investigators, alo...
# Hostel: Part II          Three American college students studying abroa...
# Step Up 2: The Streets   Romantic sparks occur between two dance studen...
# Search Party             A pair of friends embark on a mission to reuni...
# Nine Lives               A stuffy businessman finds himself trapped ins...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# Split                      M. Night Shyamalan
# Sing                     Christophe Lourdelet
# Suicide Squad                      David Ayer
# ...                                       ...
# Secret in Their Eyes                Billy Ray
# Hostel: Part II                      Eli Roth
# Step Up 2: The Streets             Jon M. Chu
# Search Party                   Scot Armstrong
# Nine Lives                   Barry Sonnenfeld
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Split                    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# Sing                     Matthew McConaughey,Reese Witherspoon, Seth Ma...
# Suicide Squad            Will Smith, Jared Leto, Margot Robbie, Viola D...
# ...                                                                    ...
# Secret in Their Eyes     Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...
# Hostel: Part II          Lauren German, Heather Matarazzo, Bijou Philli...
# Step Up 2: The Streets   Robert Hoffman, Briana Evigan, Cassie Ventura,...
# Search Party             Adam Pally, T.J. Miller, Thomas Middleditch,Sh...
# Nine Lives               Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...
#
#                          Year  Runtime (Minutes)  Rating   Votes  \
# Title
# Guardians of the Galaxy  2014                121     8.1  757074
# Prometheus               2012                124     7.0  485820
# Split                    2016                117     7.3  157606
# Sing                     2016                108     7.2   60545
# Suicide Squad            2016                123     6.2  393727
# ...                       ...                ...     ...     ...
# Secret in Their Eyes     2015                111     6.2   27585
# Hostel: Part II          2007                 94     5.5   73152
# Step Up 2: The Streets   2008                 98     6.2   70699
# Search Party             2014                 93     5.6    4881
# Nine Lives               2016                 87     5.3   12435
#
#                          Revenue (Millions)  Metascore
# Title
# Guardians of the Galaxy              333.13       76.0
# Prometheus                           126.46       65.0
# Split                                138.12       62.0
# Sing                                 270.32       59.0
# Suicide Squad                        325.02       40.0
# ...                                     ...        ...
# Secret in Their Eyes                    NaN       45.0
# Hostel: Part II                       17.54       46.0
# Step Up 2: The Streets                58.01       50.0
# Search Party                            NaN       22.0
# Nine Lives                            19.64       11.0
#
# [1000 rows x 11 columns]

# %%
Movie_indexed.sample(10)
# Out:
#                                                     Rank  \
# Title
# Cars                                                 222
# In Bruges                                            753
# Eastern Promises                                     659
# The 5th Wave                                         317
# Absolutely Anything                                  399
# Spectre                                              170
# Alexander and the Terrible, Horrible, No Good, ...   863
# Love                                                 186
# Public Enemies                                       656
# There Will Be Blood                                  300
#
#                                                                          Genre  \
# Title
# Cars                                                Animation,Adventure,Comedy
# In Bruges                                                   Comedy,Crime,Drama
# Eastern Promises                                           Crime,Drama,Mystery
# The 5th Wave                                           Action,Adventure,Sci-Fi
# Absolutely Anything                                              Comedy,Sci-Fi
# Spectre                                              Action,Adventure,Thriller
# Alexander and the Terrible, Horrible, No Good, ...               Comedy,Family
# Love                                                             Drama,Romance
# Public Enemies                                           Biography,Crime,Drama
# There Will Be Blood                                              Drama,History
#
#                                                                                           Description  \
# Title
# Cars                                                A hot-shot race-car named Lightning McQueen ge...
# In Bruges                                           Guilt-stricken after a job gone wrong, hitman ...
# Eastern Promises                                    A Russian teenager living in London who dies d...
# The 5th Wave                                        Four waves of increasingly deadly alien attack...
# Absolutely Anything                                 A group of eccentric aliens confer a human bei...
# Spectre                                             A cryptic message from Bond's past sends him o...
# Alexander and the Terrible, Horrible, No Good, ...  Alexander's day begins with gum stuck in his h...
# Love                                                Murphy is an American living in Paris who ente...
# Public Enemies                                      The Feds try to take down notorious American g...
# There Will Be Blood                                 A story of family, religion, hatred, oil and m...
#
#                                                                 Director  \
# Title
# Cars                                                       John Lasseter
# In Bruges                                                Martin McDonagh
# Eastern Promises                                        David Cronenberg
# The 5th Wave                                                  J Blakeson
# Absolutely Anything                                          Terry Jones
# Spectre                                                       Sam Mendes
# Alexander and the Terrible, Horrible, No Good, ...         Miguel Arteta
# Love                                                          Gaspar Noé
# Public Enemies                                              Michael Mann
# There Will Be Blood                                 Paul Thomas Anderson
#
#                                                                                                Actors  \
# Title
# Cars                                                Owen Wilson, Bonnie Hunt, Paul Newman, Larry t...
# In Bruges                                           Colin Farrell, Brendan Gleeson, Ciarán Hinds,E...
# Eastern Promises                                    Naomi Watts, Viggo Mortensen, Armin Mueller-St...
# The 5th Wave                                        Chloë Grace Moretz, Matthew Zuk, Gabriela Lope...
# Absolutely Anything                                 Simon Pegg, Kate Beckinsale, Sanjeev Bhaskar, ...
# Spectre                                             Daniel Craig, Christoph Waltz, Léa Seydoux, Ra...
# Alexander and the Terrible, Horrible, No Good, ...  Steve Carell, Jennifer Garner, Ed Oxenbould, D...
# Love                                                Aomi Muyock, Karl Glusman, Klara Kristin, Juan...
# Public Enemies                                      Christian Bale, Johnny Depp, Christian Stolte,...
# There Will Be Blood                                 Daniel Day-Lewis, Paul Dano, Ciarán Hinds,Mart...
#
#                                                     Year  Runtime (Minutes)  \
# Title
# Cars                                                2006                117
# In Bruges                                           2008                107
# Eastern Promises                                    2007                100
# The 5th Wave                                        2016                112
# Absolutely Anything                                 2015                 85
# Spectre                                             2015                148
# Alexander and the Terrible, Horrible, No Good, ...  2014                 81
# Love                                                2015                135
# Public Enemies                                      2009                140
# There Will Be Blood                                 2007                158
#
#                                                     Rating   Votes  \
# Title
# Cars                                                   7.1  283445
# In Bruges                                              7.9  322536
# Eastern Promises                                       7.7  198006
# The 5th Wave                                           5.2   73093
# Absolutely Anything                                    6.0   26587
# Spectre                                                6.8  308981
# Alexander and the Terrible, Horrible, No Good, ...     6.2   32310
# Love                                                   6.0   24003
# Public Enemies                                         7.0  240323
# There Will Be Blood                                    8.1  400682
#
#                                                     Revenue (Millions)  \
# Title
# Cars                                                            244.05
# In Bruges                                                         7.76
# Eastern Promises                                                 17.11
# The 5th Wave                                                     34.91
# Absolutely Anything                                                NaN
# Spectre                                                         200.07
# Alexander and the Terrible, Horrible, No Good, ...               66.95
# Love                                                               NaN
# Public Enemies                                                   97.03
# There Will Be Blood                                              40.22
#
#                                                     Metascore
# Title
# Cars                                                     73.0
# In Bruges                                                67.0
# Eastern Promises                                         82.0
# The 5th Wave                                             33.0
# Absolutely Anything                                      31.0
# Spectre                                                  60.0
# Alexander and the Terrible, Horrible, No Good, ...       54.0
# Love                                                     51.0
# Public Enemies                                           70.0
# There Will Be Blood                                      92.0

# %%
# If you are having trouble reading your file, try finding the path.  
    # Right click on your data set, on the pop-up menu select "Copy Path" then paste it into your read_csv() function.

# %%
# Read data with specified explicit index



#print(data_indexed)

# %% [markdown]
# ### 2. View Data
# #### As we go through this section, write your own definitions of what each function does as a comment in the code box.

# %%
# Use the head() function to view the first 5 rows of the data set

Movie_indexed.head()

# %%
# Use the tail() function to view the last 5 rows of the data set

Movie_indexed.tail()

# %% [markdown]
# ### 3. Understand basic information about the data
# #### As we go through this section, write your own definitions of what each function does as a comment in the code box.

# %%
# The info() function: 

Movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
# shape:

Movie.shape
#1000 rows, 12 columns = x,y
# what information does shape provide?  what is the order?
# Out:
# (1000, 12)

# %%
# columns:


# what information does columns provide?

# %%
# The describe() function: 

Movie.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# 50%             47.985000   59.500000
# 75%            113.715000   72.000000
# max            936.630000  100.000000

# %% [markdown]
# ### 4. Data Selection -- Indexing and Slicing

# %%
#  Extract data as series
# define and print the variable 'genre'

genre = Movie['Genre']
#extract a subset column 
genre
# Out:
# 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 995         Crime,Drama,Mystery
# 996                      Horror
# 997         Drama,Music,Romance
# 998            Adventure,Comedy
# 999       Comedy,Family,Fantasy
# Name: Genre, Length: 1000, dtype: object

# %%
genre = Movie[['Genre']]
#extract a subset column in a data frame format
genre
# Out:
#                         Genre
# 0     Action,Adventure,Sci-Fi
# 1    Adventure,Mystery,Sci-Fi
# 2             Horror,Thriller
# 3     Animation,Comedy,Family
# 4    Action,Adventure,Fantasy
# ..                        ...
# 995       Crime,Drama,Mystery
# 996                    Horror
# 997       Drama,Music,Romance
# 998          Adventure,Comedy
# 999     Comedy,Family,Fantasy
#
# [1000 rows x 1 columns]

# %%
multiple_columns = Movie[['Genre', 'Title', 'Actors','Rating']]
multiple_columns
# Out:
#                         Genre                    Title  \
# 0     Action,Adventure,Sci-Fi  Guardians of the Galaxy
# 1    Adventure,Mystery,Sci-Fi               Prometheus
# 2             Horror,Thriller                    Split
# 3     Animation,Comedy,Family                     Sing
# 4    Action,Adventure,Fantasy            Suicide Squad
# ..                        ...                      ...
# 995       Crime,Drama,Mystery     Secret in Their Eyes
# 996                    Horror          Hostel: Part II
# 997       Drama,Music,Romance   Step Up 2: The Streets
# 998          Adventure,Comedy             Search Party
# 999     Comedy,Family,Fantasy               Nine Lives
#
#                                                 Actors  Rating
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...     8.1
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...     7.0
# 2    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...     7.3
# 3    Matthew McConaughey,Reese Witherspoon, Seth Ma...     7.2
# 4    Will Smith, Jared Leto, Margot Robbie, Viola D...     6.2
# ..                                                 ...     ...
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...     6.2
# 996  Lauren German, Heather Matarazzo, Bijou Philli...     5.5
# 997  Robert Hoffman, Briana Evigan, Cassie Ventura,...     6.2
# 998  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...     5.6
# 999  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...     5.3
#
# [1000 rows x 4 columns]

# %% [raw]
# # Extract data using rows

# %%
# iloc function
# loc function
#locates rows by name, retrieve data from that specified row.

Movie_indexed.loc[['Split']]
# Out:
#        Rank            Genre  \
# Title
# Split     3  Horror,Thriller
#
#                                              Description            Director  \
# Title
# Split  Three girls are kidnapped by a man with a diag...  M. Night Shyamalan
#
#                                                   Actors  Year  \
# Title
# Split  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016
#
#        Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# Title
# Split                117     7.3  157606              138.12       62.0

# %% [markdown]
# ### 5. Data Selection - Based on Conditional Filtering

# %%
# Use the code block to select movies that have been release between 2010-2016, with a rating of less than 6.0, but generated a signifianct (top) revenue.

Movie[(Movie['Year'] >= 2010) & (Movie['Year'] <= 2016)
    & (Movie['Rating'] < 6.0)
    & (Movie['Revenue (Millions)'] >  Movie['Revenue (Millions)'].quantile(0.85))]
# Out:
#      Rank                                      Title                    Genre  \
# 63     64                       Fifty Shades of Grey   Drama,Romance,Thriller
# 126   127            Transformers: Age of Extinction  Action,Adventure,Sci-Fi
# 366   367  The Twilight Saga: Breaking Dawn - Part 2  Adventure,Drama,Fantasy
# 657   658               Teenage Mutant Ninja Turtles  Action,Adventure,Comedy
# 925   926  The Twilight Saga: Breaking Dawn - Part 1  Adventure,Drama,Fantasy
# 941   942                 The Twilight Saga: Eclipse  Adventure,Drama,Fantasy
#
#                                            Description            Director  \
# 63   Literature student Anastasia Steele's life cha...  Sam Taylor-Johnson
# 126  Autobots must escape sight from a bounty hunte...         Michael Bay
# 366  After the birth of Renesmee, the Cullens gathe...         Bill Condon
# 657  When a kingpin threatens New York City, a grou...  Jonathan Liebesman
# 925  The Quileutes close in on expecting parents Ed...         Bill Condon
# 941  As a string of mysterious killings grips Seatt...         David Slade
#
#                                                 Actors  Year  \
# 63   Dakota Johnson, Jamie Dornan, Jennifer Ehle,El...  2015
# 126  Mark Wahlberg, Nicola Peltz, Jack Reynor, Stan...  2014
# 366  Kristen Stewart, Robert Pattinson, Taylor Laut...  2012
# 657  Megan Fox, Will Arnett, William Fichtner, Noel...  2014
# 925  Kristen Stewart, Robert Pattinson, Taylor Laut...  2011
# 941  Kristen Stewart, Robert Pattinson, Taylor Laut...  2010
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 63                 125     4.1  244474              166.15       46.0
# 126                165     5.7  255483              245.43       32.0
# 366                115     5.5  194329              292.30       52.0
# 657                101     5.9  178527              190.87       31.0
# 925                117     4.9  190244              281.28       45.0
# 941                124     4.9  192740              300.52       58.0

# %%
# Note: The article is expecting more than 1 Twilight movie at the time of publishing.  
#To find the second Twilight movie, try manipulating the quantile value.  
#How specific can you get?
